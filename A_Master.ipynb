# %% [markdown]
# # Useful Function or Code Blocks

# %%
# Upload files to Colab
from google.colab import files
uploaded = files.upload() # the uploaded object is a dictionary having the filename and content as it's key-value pairs
# Download the files
files.download("/content/sample_data/mnist.pkl")

# Write file directly to Google Drive from Colab
! touch "/content/drive/MyDrive/sample_file.txt"
